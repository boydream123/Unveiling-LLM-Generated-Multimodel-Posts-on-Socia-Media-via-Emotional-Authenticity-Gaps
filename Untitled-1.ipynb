# %%
# !git clone https://github.com/boydream123/Unveiling-LLM-Generated-Multimodel-Posts-on-Socia-Media-via-Emotional-Authenticity-Gaps.git
# !cd Unveiling-LLM-Generated-Multimodel-Posts-on-Socia-Media-via-Emotional-Authenticity-Gaps
# Out:
# Cloning into 'Unveiling-LLM-Generated-Multimodel-Posts-on-Socia-Media-via-Emotional-Authenticity-Gaps'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17 (delta 2), reused 13 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (17/17), 8.34 KiB | 8.34 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# !ls
# Out:
# sample_data
# Unveiling-LLM-Generated-Multimodel-Posts-on-Socia-Media-via-Emotional-Authenticity-Gaps

# %%
# !nvidia-smi
# Out:
# Tue Nov 18 12:42:46 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             42W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !python Unveiling-LLM-Generated-Multimodel-Posts-on-Socia-Media-via-Emotional-Authenticity-Gaps/train.py \
  --lmm_model_name "Qwen/Qwen2-VL-1.5B-Instruct" \
  --batch_size 2 \
  --epochs 5 \
  --learning_rate 2e-5 \
  --lambda_emo 0.1 \
  --save_path "checkpoints/eagle_qwen_1.5B_heads.pth"
# Out:
# 2025-11-18 12:41:48.030114: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-18 12:41:48.047930: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763469708.069157    2777 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763469708.075494    2777 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763469708.091594    2777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763469708.091618    2777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763469708.091621    2777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763469708.091624    2777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-18 12:41:48.096486: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/Unveiling-LLM-Generated-Multimodel-Posts-on-Socia-Media-via-Emotional-Authenticity-Gaps/train.py", line 5, in <module>
#     from transformers import AutoProcessor, AdamW
# ImportError: cannot import name 'AdamW' from 'transformers' (/usr/local/lib/python3.12/dist-packages/transformers/__init__.py)
